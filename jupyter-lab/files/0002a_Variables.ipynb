# %% [markdown]
# - Las variables son contenedores para guardar valores de datos.

# %% [markdown]
# ## Creación de Variables
# - Python no tiene un comando para la declaración de variables.
#
# - En Python, las variables son creadas en el momento en el que le asignas un valor

# %%
x = 5
y = "John"
print(x)
print(y)
# Out:
# 5
# John

# %% [markdown]
# - Las variables no necesitan ser declaradas con algún tipo en particular, y pueden cambiar de tipo después de que han sido creadas.

# %%
x = 4       # x is of type int
x = "Sally" # x is now of type str
print(x)
# Out:
# Sally

# %%
ruta_y_nombre_archivo0 = 'data/raw/Sleep_health_and_lifestyle_dataset_0.csv'
print(ruta_y_nombre_archivo0)
# Out:
# data/raw/Sleep_health_and_lifestyle_dataset_0.csv

# %%
import pandas as pd
tabla0 = pd.read_csv(ruta_y_nombre_archivo0)
tabla0
# Out:
#     Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0           1    Male   27     Software Engineer             6.1
# 1           2    Male   28                Doctor             6.2
# 2           3    Male   28                Doctor             6.2
# 3           4    Male   28  Sales Representative             5.9
# 4           5    Male   28  Sales Representative             5.9
# 5           6    Male   28     Software Engineer             5.9
# 6           7    Male   29               Teacher             6.3
# 7           8    Male   29                Doctor             7.8
# 8           9    Male   29                Doctor             7.8
# 9          10    Male   29                Doctor             7.8
# 10         11    Male   29                Doctor             6.1
# 11         12    Male   29                Doctor             7.8
# 12         13    Male   29                Doctor             6.1
# 13         14    Male   29                Doctor             6.0
# 14         15    Male   29                Doctor             6.0
# 15         16    Male   29                Doctor             6.0
# 16         17  Female   29                 Nurse             6.5
# 17         18    Male   29                Doctor             6.0
# 18         19  Female   29                 Nurse             6.5
# 19         20    Male   30                Doctor             7.6
# 20         21    Male   30                Doctor             7.7
# 21         22    Male   30                Doctor             7.7
# 22         23    Male   30                Doctor             7.7
# 23         24    Male   30                Doctor             7.7
# 24         25    Male   30                Doctor             7.8
# 25         26    Male   30                Doctor             7.9
# 26         27    Male   30                Doctor             7.8
# 27         28    Male   30                Doctor             7.9
# 28         29    Male   30                Doctor             7.9
# 29         30    Male   30                Doctor             7.9
# 30         31  Female   30                 Nurse             6.4
# 31         32  Female   30                 Nurse             6.4
# 32         33  Female   31                 Nurse             7.9
# 33         34    Male   31                Doctor             6.1
# 34         35    Male   31                Doctor             7.7
# 35         36    Male   31                Doctor             6.1
# 36         37    Male   31                Doctor             6.1
# 37         38    Male   31                Doctor             7.6
# 38         39    Male   31                Doctor             7.6
# 39         40    Male   31                Doctor             7.6
# 40         41    Male   31                Doctor             7.7
# 41         42    Male   31                Doctor             7.7
# 42         43    Male   31                Doctor             7.7
#
#     Quality of Sleep  Physical Activity Level  Stress Level   BMI Category  \
# 0                  6                       42             6     Overweight
# 1                  6                       60             8         Normal
# 2                  6                       60             8         Normal
# 3                  4                       30             8          Obese
# 4                  4                       30             8          Obese
# 5                  4                       30             8          Obese
# 6                  6                       40             7          Obese
# 7                  7                       75             6         Normal
# 8                  7                       75             6         Normal
# 9                  7                       75             6         Normal
# 10                 6                       30             8         Normal
# 11                 7                       75             6         Normal
# 12                 6                       30             8         Normal
# 13                 6                       30             8         Normal
# 14                 6                       30             8         Normal
# 15                 6                       30             8         Normal
# 16                 5                       40             7  Normal Weight
# 17                 6                       30             8         Normal
# 18                 5                       40             7  Normal Weight
# 19                 7                       75             6         Normal
# 20                 7                       75             6         Normal
# 21                 7                       75             6         Normal
# 22                 7                       75             6         Normal
# 23                 7                       75             6         Normal
# 24                 7                       75             6         Normal
# 25                 7                       75             6         Normal
# 26                 7                       75             6         Normal
# 27                 7                       75             6         Normal
# 28                 7                       75             6         Normal
# 29                 7                       75             6         Normal
# 30                 5                       35             7  Normal Weight
# 31                 5                       35             7  Normal Weight
# 32                 8                       75             4  Normal Weight
# 33                 6                       30             8         Normal
# 34                 7                       75             6         Normal
# 35                 6                       30             8         Normal
# 36                 6                       30             8         Normal
# 37                 7                       75             6         Normal
# 38                 7                       75             6         Normal
# 39                 7                       75             6         Normal
# 40                 7                       75             6         Normal
# 41                 7                       75             6         Normal
# 42                 7                       75             6         Normal
#
#    Blood Pressure  Heart Rate  Daily Steps
# 0          126/83          77         4200
# 1          125/80          75        10000
# 2          125/80          75        10000
# 3          140/90          85         3000
# 4          140/90          85         3000
# 5          140/90          85         3000
# 6          140/90          82         3500
# 7          120/80          70         8000
# 8          120/80          70         8000
# 9          120/80          70         8000
# 10         120/80          70         8000
# 11         120/80          70         8000
# 12         120/80          70         8000
# 13         120/80          70         8000
# 14         120/80          70         8000
# 15         120/80          70         8000
# 16         132/87          80         4000
# 17         120/80          70         8000
# 18         132/87          80         4000
# 19         120/80          70         8000
# 20         120/80          70         8000
# 21         120/80          70         8000
# 22         120/80          70         8000
# 23         120/80          70         8000
# 24         120/80          70         8000
# 25         120/80          70         8000
# 26         120/80          70         8000
# 27         120/80          70         8000
# 28         120/80          70         8000
# 29         120/80          70         8000
# 30         130/86          78         4100
# 31         130/86          78         4100
# 32         117/76          69         6800
# 33         125/80          72         5000
# 34         120/80          70         8000
# 35         125/80          72         5000
# 36         125/80          72         5000
# 37         120/80          70         8000
# 38         120/80          70         8000
# 39         120/80          70         8000
# 40         120/80          70         8000
# 41         120/80          70         8000
# 42         120/80          70         8000

# %%
import pandas as pd

# %%
ruta_y_nombre_archivo1a = '../data/raw/Sleep_health_and_lifestyle_dataset_1.csv'
print(ruta_y_nombre_archivo1a)
tabla1a = pd.read_csv(ruta_y_nombre_archivo1a)
tabla1a
# Out:
# ../data/raw/Sleep_health_and_lifestyle_dataset_1.csv
#     Person ID  Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0          39    Male   31      Doctor             7.6                 7
# 1          40    Male   31      Doctor             7.6                 7
# 2          41    Male   31      Doctor             7.7                 7
# 3          42    Male   31      Doctor             7.7                 7
# 4          43    Male   31      Doctor             7.7                 7
# 5          44    Male   31      Doctor             7.8                 7
# 6          45    Male   31      Doctor             7.7                 7
# 7          46    Male   31      Doctor             7.8                 7
# 8          47    Male   31      Doctor             7.7                 7
# 9          48    Male   31      Doctor             7.8                 7
# 10         49    Male   31      Doctor             7.7                 7
# 11         50    Male   31      Doctor             7.7                 7
# 12         51    Male   32    Engineer             7.5                 8
# 13         52    Male   32    Engineer             7.5                 8
# 14         53    Male   32      Doctor             6.0                 6
# 15         54    Male   32      Doctor             7.6                 7
# 16         55    Male   32      Doctor             6.0                 6
# 17         56    Male   32      Doctor             6.0                 6
# 18         57    Male   32      Doctor             7.7                 7
# 19         58    Male   32      Doctor             6.0                 6
# 20         59    Male   32      Doctor             6.0                 6
# 21         60    Male   32      Doctor             7.7                 7
# 22         61    Male   32      Doctor             6.0                 6
# 23         62    Male   32      Doctor             6.0                 6
# 24         63    Male   32      Doctor             6.2                 6
# 25         64    Male   32      Doctor             6.2                 6
# 26         65    Male   32      Doctor             6.2                 6
# 27         66    Male   32      Doctor             6.2                 6
# 28         67    Male   32  Accountant             7.2                 8
# 29         68    Male   33      Doctor             6.0                 6
# 30         69  Female   33   Scientist             6.2                 6
# 31         70  Female   33   Scientist             6.2                 6
# 32         71    Male   33      Doctor             6.1                 6
# 33         72    Male   33      Doctor             6.1                 6
# 34         73    Male   33      Doctor             6.1                 6
# 35         74    Male   33      Doctor             6.1                 6
# 36         75    Male   33      Doctor             6.0                 6
# 37         76    Male   33      Doctor             6.0                 6
# 38         77    Male   33      Doctor             6.0                 6
# 39         78    Male   33      Doctor             6.0                 6
# 40         79    Male   33      Doctor             6.0                 6
# 41         80    Male   33      Doctor             6.0                 6
# 42         81  Female   34   Scientist             5.8                 4
#
#     Physical Activity Level  Stress Level   BMI Category Blood Pressure  \
# 0                        75             6         Normal         120/80
# 1                        75             6         Normal         120/80
# 2                        75             6         Normal         120/80
# 3                        75             6         Normal         120/80
# 4                        75             6         Normal         120/80
# 5                        75             6         Normal         120/80
# 6                        75             6         Normal         120/80
# 7                        75             6         Normal         120/80
# 8                        75             6         Normal         120/80
# 9                        75             6         Normal         120/80
# 10                       75             6         Normal         120/80
# 11                       75             6         Normal         120/80
# 12                       45             3         Normal         120/80
# 13                       45             3         Normal         120/80
# 14                       30             8         Normal         125/80
# 15                       75             6         Normal         120/80
# 16                       30             8         Normal         125/80
# 17                       30             8         Normal         125/80
# 18                       75             6         Normal         120/80
# 19                       30             8         Normal         125/80
# 20                       30             8         Normal         125/80
# 21                       75             6         Normal         120/80
# 22                       30             8         Normal         125/80
# 23                       30             8         Normal         125/80
# 24                       30             8         Normal         125/80
# 25                       30             8         Normal         125/80
# 26                       30             8         Normal         125/80
# 27                       30             8         Normal         125/80
# 28                       50             6  Normal Weight         118/76
# 29                       30             8         Normal         125/80
# 30                       50             6     Overweight         128/85
# 31                       50             6     Overweight         128/85
# 32                       30             8         Normal         125/80
# 33                       30             8         Normal         125/80
# 34                       30             8         Normal         125/80
# 35                       30             8         Normal         125/80
# 36                       30             8         Normal         125/80
# 37                       30             8         Normal         125/80
# 38                       30             8         Normal         125/80
# 39                       30             8         Normal         125/80
# 40                       30             8         Normal         125/80
# 41                       30             8         Normal         125/80
# 42                       32             8     Overweight         131/86
#
#     Heart Rate  Daily Steps
# 0           70         8000
# 1           70         8000
# 2           70         8000
# 3           70         8000
# 4           70         8000
# 5           70         8000
# 6           70         8000
# 7           70         8000
# 8           70         8000
# 9           70         8000
# 10          70         8000
# 11          70         8000
# 12          70         8000
# 13          70         8000
# 14          72         5000
# 15          70         8000
# 16          72         5000
# 17          72         5000
# 18          70         8000
# 19          72         5000
# 20          72         5000
# 21          70         8000
# 22          72         5000
# 23          72         5000
# 24          72         5000
# 25          72         5000
# 26          72         5000
# 27          72         5000
# 28          68         7000
# 29          72         5000
# 30          76         5500
# 31          76         5500
# 32          72         5000
# 33          72         5000
# 34          72         5000
# 35          72         5000
# 36          72         5000
# 37          72         5000
# 38          72         5000
# 39          72         5000
# 40          72         5000
# 41          72         5000
# 42          81         5200

# %%
! pwd
# Out:
# /app/my_data

# %%
#ruta_y_nombre_archivo1 = '/Users/josealfredomendezbarrera/Documents/prsnl/DSCertification_FMAT/data/raw/Sleep_health_and_lifestyle_dataset_1.csv'
ruta_y_nombre_archivo1 = 'data/raw/Sleep_health_and_lifestyle_dataset_1.csv'
print(ruta_y_nombre_archivo1)
tabla1 = pd.read_csv(ruta_y_nombre_archivo1)
tabla1
# Out:
# data/raw/Sleep_health_and_lifestyle_dataset_1.csv
#     Person ID  Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0          39    Male   31      Doctor             7.6                 7
# 1          40    Male   31      Doctor             7.6                 7
# 2          41    Male   31      Doctor             7.7                 7
# 3          42    Male   31      Doctor             7.7                 7
# 4          43    Male   31      Doctor             7.7                 7
# 5          44    Male   31      Doctor             7.8                 7
# 6          45    Male   31      Doctor             7.7                 7
# 7          46    Male   31      Doctor             7.8                 7
# 8          47    Male   31      Doctor             7.7                 7
# 9          48    Male   31      Doctor             7.8                 7
# 10         49    Male   31      Doctor             7.7                 7
# 11         50    Male   31      Doctor             7.7                 7
# 12         51    Male   32    Engineer             7.5                 8
# 13         52    Male   32    Engineer             7.5                 8
# 14         53    Male   32      Doctor             6.0                 6
# 15         54    Male   32      Doctor             7.6                 7
# 16         55    Male   32      Doctor             6.0                 6
# 17         56    Male   32      Doctor             6.0                 6
# 18         57    Male   32      Doctor             7.7                 7
# 19         58    Male   32      Doctor             6.0                 6
# 20         59    Male   32      Doctor             6.0                 6
# 21         60    Male   32      Doctor             7.7                 7
# 22         61    Male   32      Doctor             6.0                 6
# 23         62    Male   32      Doctor             6.0                 6
# 24         63    Male   32      Doctor             6.2                 6
# 25         64    Male   32      Doctor             6.2                 6
# 26         65    Male   32      Doctor             6.2                 6
# 27         66    Male   32      Doctor             6.2                 6
# 28         67    Male   32  Accountant             7.2                 8
# 29         68    Male   33      Doctor             6.0                 6
# 30         69  Female   33   Scientist             6.2                 6
# 31         70  Female   33   Scientist             6.2                 6
# 32         71    Male   33      Doctor             6.1                 6
# 33         72    Male   33      Doctor             6.1                 6
# 34         73    Male   33      Doctor             6.1                 6
# 35         74    Male   33      Doctor             6.1                 6
# 36         75    Male   33      Doctor             6.0                 6
# 37         76    Male   33      Doctor             6.0                 6
# 38         77    Male   33      Doctor             6.0                 6
# 39         78    Male   33      Doctor             6.0                 6
# 40         79    Male   33      Doctor             6.0                 6
# 41         80    Male   33      Doctor             6.0                 6
# 42         81  Female   34   Scientist             5.8                 4
#
#     Physical Activity Level  Stress Level   BMI Category Blood Pressure  \
# 0                        75             6         Normal         120/80
# 1                        75             6         Normal         120/80
# 2                        75             6         Normal         120/80
# 3                        75             6         Normal         120/80
# 4                        75             6         Normal         120/80
# 5                        75             6         Normal         120/80
# 6                        75             6         Normal         120/80
# 7                        75             6         Normal         120/80
# 8                        75             6         Normal         120/80
# 9                        75             6         Normal         120/80
# 10                       75             6         Normal         120/80
# 11                       75             6         Normal         120/80
# 12                       45             3         Normal         120/80
# 13                       45             3         Normal         120/80
# 14                       30             8         Normal         125/80
# 15                       75             6         Normal         120/80
# 16                       30             8         Normal         125/80
# 17                       30             8         Normal         125/80
# 18                       75             6         Normal         120/80
# 19                       30             8         Normal         125/80
# 20                       30             8         Normal         125/80
# 21                       75             6         Normal         120/80
# 22                       30             8         Normal         125/80
# 23                       30             8         Normal         125/80
# 24                       30             8         Normal         125/80
# 25                       30             8         Normal         125/80
# 26                       30             8         Normal         125/80
# 27                       30             8         Normal         125/80
# 28                       50             6  Normal Weight         118/76
# 29                       30             8         Normal         125/80
# 30                       50             6     Overweight         128/85
# 31                       50             6     Overweight         128/85
# 32                       30             8         Normal         125/80
# 33                       30             8         Normal         125/80
# 34                       30             8         Normal         125/80
# 35                       30             8         Normal         125/80
# 36                       30             8         Normal         125/80
# 37                       30             8         Normal         125/80
# 38                       30             8         Normal         125/80
# 39                       30             8         Normal         125/80
# 40                       30             8         Normal         125/80
# 41                       30             8         Normal         125/80
# 42                       32             8     Overweight         131/86
#
#     Heart Rate  Daily Steps
# 0           70         8000
# 1           70         8000
# 2           70         8000
# 3           70         8000
# 4           70         8000
# 5           70         8000
# 6           70         8000
# 7           70         8000
# 8           70         8000
# 9           70         8000
# 10          70         8000
# 11          70         8000
# 12          70         8000
# 13          70         8000
# 14          72         5000
# 15          70         8000
# 16          72         5000
# 17          72         5000
# 18          70         8000
# 19          72         5000
# 20          72         5000
# 21          70         8000
# 22          72         5000
# 23          72         5000
# 24          72         5000
# 25          72         5000
# 26          72         5000
# 27          72         5000
# 28          68         7000
# 29          72         5000
# 30          76         5500
# 31          76         5500
# 32          72         5000
# 33          72         5000
# 34          72         5000
# 35          72         5000
# 36          72         5000
# 37          72         5000
# 38          72         5000
# 39          72         5000
# 40          72         5000
# 41          72         5000
# 42          81         5200

# %% [markdown]
# ## Casting

# %% [markdown]
# - Si se prefiere o necesita especificar el tipo de dato de una variable, esto puede ser realizado con un *casteo*.

# %%
x = str(3)    # x will be '3'
y = int(3)    # y will be 3
z = float(3)  # z will be 3.0
print(x)
print(y)
print(z)
# Out:
# 3
# 3
# 3.0

# %% [markdown]
# ## Obtener el tipo de dato

# %% [markdown]
# - Se puede obtener el tipo de dato de una variable con la función `type()`.

# %%
x = 5
y = "John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# - String variables can be declared either by using single or double quotes:

# %%
type(tabla1a)
# Out:
# pandas.core.frame.DataFrame

# %%
tabla1a['Person ID']
# Out:
# 0     39
# 1     40
# 2     41
# 3     42
# 4     43
# 5     44
# 6     45
# 7     46
# 8     47
# 9     48
# 10    49
# 11    50
# 12    51
# 13    52
# 14    53
# 15    54
# 16    55
# 17    56
# 18    57
# 19    58
# 20    59
# 21    60
# 22    61
# 23    62
# 24    63
# 25    64
# 26    65
# 27    66
# 28    67
# 29    68
# 30    69
# 31    70
# 32    71
# 33    72
# 34    73
# 35    74
# 36    75
# 37    76
# 38    77
# 39    78
# 40    79
# 41    80
# 42    81
# Name: Person ID, dtype: int64

# %%
type(tabla1a['Person ID'])
# Out:
# pandas.core.series.Series

# %%
len(tabla1a)
# Out:
# 43

# %%
tabla1a['Person ID'][42]
# Out:
# 81

# %%
type(tabla1a['Person ID'][42])
# Out:
# numpy.int64

# %%
tabla1a['Occupation']
# Out:
# 0         Doctor
# 1         Doctor
# 2         Doctor
# 3         Doctor
# 4         Doctor
# 5         Doctor
# 6         Doctor
# 7         Doctor
# 8         Doctor
# 9         Doctor
# 10        Doctor
# 11        Doctor
# 12      Engineer
# 13      Engineer
# 14        Doctor
# 15        Doctor
# 16        Doctor
# 17        Doctor
# 18        Doctor
# 19        Doctor
# 20        Doctor
# 21        Doctor
# 22        Doctor
# 23        Doctor
# 24        Doctor
# 25        Doctor
# 26        Doctor
# 27        Doctor
# 28    Accountant
# 29        Doctor
# 30     Scientist
# 31     Scientist
# 32        Doctor
# 33        Doctor
# 34        Doctor
# 35        Doctor
# 36        Doctor
# 37        Doctor
# 38        Doctor
# 39        Doctor
# 40        Doctor
# 41        Doctor
# 42     Scientist
# Name: Occupation, dtype: object

# %%
tabla1a.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps'],
#       dtype='object')

# %%
type(tabla1a['Occupation'][0])
# Out:
# str

# %%
x = "John"
# is the same as
x = 'John'

# %% [markdown]
# ## Case-Sensitive

# %% [markdown]
# - Las variables son *case-sensitive*.

# %%
a = 4
A = "Sally"
#A will not overwrite a
print(a)
print(A)
# Out:
# 4
# Sally

# %% [markdown]
# [Python: Nombre de Variables](https://www.w3schools.com/python/python_variables_names.asp)

# %% [markdown]
# =========================
# =========================

# %% [markdown]
# # Asignar múltiples valores

# %% [markdown]
# ## Varios valores a múltiples variables
# - Python permite asignar valores a múltiples variables en una línea:

# %%
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %% [markdown]
# ## Un valor a múltiples variables
#
# - También es posible asignar el mismo valor a múltiples variables en una línea:

# %%
x = y = z = "Orange"
print(x)
print(y)
print(z)
# Out:
# Orange
# Orange
# Orange

# %% [markdown]
# ## Desempaquetar una colección de datos
# - Si se tiene una colección o arreglo de valores en una lista, tuple, etc, Python permite extraer los valores en variables:

# %%
fruits = ["apple", "banana", "cherry"]
print(fruits)
x, y, z = fruits
print(x)
print(y)
print(z)
# Out:
# ['apple', 'banana', 'cherry']
# apple
# banana
# cherry

# %% [markdown]
# - Más acerca de [desempaquetar `tuples`](https://www.w3schools.com/python/python_tuples_unpack.asp)

# %% [markdown]
# ## Variables Globales
#
# - Las variables que son creadas fuera de una función son conocidas como **variables globales**
#
# - Las variables globales pueden ser usadas por cualquiera, tanto dentro como fuera de funciones

# %%
x = "awesome"

def myfunc():
  print("Python is " + x)

myfunc()
# Out:
# Python is awesome

# %%
def reading_a_file(x):
  print("Leeremos el siguiente archivo: \n \n " + x)

reading_a_file(x=ruta_y_nombre_archivo0)
# Out:
# Leeremos el siguiente archivo:
#
#  data/raw/Sleep_health_and_lifestyle_dataset_0.csv

# %%
reading_a_file(x=ruta_y_nombre_archivo1a)
# Out:
# Leeremos el siguiente archivo:
#
#  ../data/raw/Sleep_health_and_lifestyle_dataset_1.csv

# %% [markdown]
# - Si se ha creado una variable dentro de una función, ésta será local y sólo podrá ser usada adentro de la función. La variable global con el mismo nombre se mantendrá global y con su valor original
#
# If you create a variable with the same name inside a function, this variable will be local, and can only be used inside the function. The global variable with the same name will remain as it was, global and with the original value.

# %%
def sumcols(tabla, columna1, columna2):
    return tabla[columna1]+tabla[columna2]

# %%
#sumcols(tabla = tabla1a.tail(5).append(tabla1a.head(5)), columna1 = 'Sleep Duration', columna2 = 'Quality of Sleep')
sumcols(tabla = pd.concat([tabla1a.tail(5),tabla1a.head(5)]), columna1 = 'Sleep Duration', columna2 = 'Quality of Sleep')
# Out:
# 38    12.0
# 39    12.0
# 40    12.0
# 41    12.0
# 42     9.8
# 0     14.6
# 1     14.6
# 2     14.7
# 3     14.7
# 4     14.7
# dtype: float64

# %%
tabla1a.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps'],
#       dtype='object')

# %%
type(tabla1a['Age'][0])
# Out:
# numpy.int64

# %%
type(tabla1a['Sleep Duration'][0])
# Out:
# numpy.float64

# %%
sumcols(tabla = pd.concat([tabla1a.tail(5),tabla1a.head(5)]), columna1 = 'Age', columna2 = 'Gender')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/venv/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:171, in _na_arithmetic_op(left, right, op, is_cmp)
#     170 try:
# --> 171     result = func(left, right)
#     172 except TypeError:
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/computation/expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/computation/expressions.py:70, in _evaluate_standard(op, op_str, a, b)
#      69     _store_test_result(False)
# ---> 70 return op(a, b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 sumcols(tabla = pd.concat([tabla1a.tail(5),tabla1a.head(5)]), columna1 = 'Age', columna2 = 'Gender')
#
# Cell In[32], line 2, in sumcols(tabla, columna1, columna2)
#       1 def sumcols(tabla, columna1, columna2):
# ----> 2     return tabla[columna1]+tabla[columna2]
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/arraylike.py:186, in OpsMixin.__add__(self, other)
#      98 @unpack_zerodim_and_defer("__add__")
#      99 def __add__(self, other):
#     100     """
#     101     Get Addition of DataFrame and other, column-wise.
#     102
#    (...)
#     184     moose     3.0     NaN
#     185     """
# --> 186     return self._arith_method(other, operator.add)
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/series.py:6112, in Series._arith_method(self, other, op)
#    6110 def _arith_method(self, other, op):
#    6111     self, other = ops.align_method_SERIES(self, other)
# -> 6112     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/base.py:1348, in IndexOpsMixin._arith_method(self, other, op)
#    1345 rvalues = ensure_wrapped_if_datetimelike(rvalues)
#    1347 with np.errstate(all="ignore"):
# -> 1348     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1350 return self._construct_result(result, name=res_name)
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:232, in arithmetic_op(left, right, op)
#     228     _bool_arith_check(op, left, right)
#     230     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     231     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 232     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     234 return res_values
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:178, in _na_arithmetic_op(left, right, op, is_cmp)
#     172 except TypeError:
#     173     if not is_cmp and (is_object_dtype(left.dtype) or is_object_dtype(right)):
#     174         # For object dtype, fallback to a masked operation (only operating
#     175         #  on the non-missing values)
#     176         # Don't do this for comparisons, as that will handle complex numbers
#     177         #  incorrectly, see GH#32047
# --> 178         result = _masked_arith_op(left, right, op)
#     179     else:
#     180         raise
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:116, in _masked_arith_op(x, y, op)
#     114     # See GH#5284, GH#5035, GH#19448 for historical reference
#     115     if mask.any():
# --> 116         result[mask] = op(xrav[mask], yrav[mask])
#     118 else:
#     119     if not is_scalar(y):
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
[

# %%
tablanueva = pd.concat([tabla1a[20:25],tabla1a[10:15]])
tablanueva
# Out:
#     Person ID Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 20         59   Male   32     Doctor             6.0                 6
# 21         60   Male   32     Doctor             7.7                 7
# 22         61   Male   32     Doctor             6.0                 6
# 23         62   Male   32     Doctor             6.0                 6
# 24         63   Male   32     Doctor             6.2                 6
# 10         49   Male   31     Doctor             7.7                 7
# 11         50   Male   31     Doctor             7.7                 7
# 12         51   Male   32   Engineer             7.5                 8
# 13         52   Male   32   Engineer             7.5                 8
# 14         53   Male   32     Doctor             6.0                 6
#
#     Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 20                       30             8       Normal         125/80
# 21                       75             6       Normal         120/80
# 22                       30             8       Normal         125/80
# 23                       30             8       Normal         125/80
# 24                       30             8       Normal         125/80
# 10                       75             6       Normal         120/80
# 11                       75             6       Normal         120/80
# 12                       45             3       Normal         120/80
# 13                       45             3       Normal         120/80
# 14                       30             8       Normal         125/80
#
#     Heart Rate  Daily Steps
# 20          72         5000
# 21          70         8000
# 22          72         5000
# 23          72         5000
# 24          72         5000
# 10          70         8000
# 11          70         8000
# 12          70         8000
# 13          70         8000
# 14          72         5000

# %%
tablanueva['Sleep Duration']
# Out:
# 20    6.0
# 21    7.7
# 22    6.0
# 23    6.0
# 24    6.2
# 10    7.7
# 11    7.7
# 12    7.5
# 13    7.5
# 14    6.0
# Name: Sleep Duration, dtype: float64

# %%
tablanueva['Sleep Duration'].astype('category') + tablanueva['Age']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 tablanueva['Sleep Duration'].astype('category') + tablanueva['Age']
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/arraylike.py:186, in OpsMixin.__add__(self, other)
#      98 @unpack_zerodim_and_defer("__add__")
#      99 def __add__(self, other):
#     100     """
#     101     Get Addition of DataFrame and other, column-wise.
#     102
#    (...)
#     184     moose     3.0     NaN
#     185     """
# --> 186     return self._arith_method(other, operator.add)
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/series.py:6112, in Series._arith_method(self, other, op)
#    6110 def _arith_method(self, other, op):
#    6111     self, other = ops.align_method_SERIES(self, other)
# -> 6112     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/base.py:1348, in IndexOpsMixin._arith_method(self, other, op)
#    1345 rvalues = ensure_wrapped_if_datetimelike(rvalues)
#    1347 with np.errstate(all="ignore"):
# -> 1348     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1350 return self._construct_result(result, name=res_name)
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:224, in arithmetic_op(left, right, op)
#     211 # NB: We assume that extract_array and ensure_wrapped_if_datetimelike
#     212 #  have already been called on `left` and `right`,
#     213 #  and `maybe_prepare_scalar_for_op` has already been called on `right`
#     214 # We need to special-case datetime64/timedelta64 dtypes (e.g. because numpy
#     215 # casts integer dtypes to timedelta64 when operating with timedelta64 - GH#22390)
#     217 if (
#     218     should_extension_dispatch(left, right)
#     219     or isinstance(right, (Timedelta, BaseOffset, Timestamp))
#    (...)
#     222     # Timedelta/Timestamp and other custom scalars are included in the check
#     223     # because numexpr will fail on it, see GH#31457
# --> 224     res_values = op(left, right)
#     225 else:
#     226     # TODO we should handle EAs consistently and move this check before the if/else
#     227     # (https://github.com/pandas-dev/pandas/issues/41165)
#     228     _bool_arith_check(op, left, right)
#
# File /opt/venv/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:1374, in Categorical.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    1370         return result
#    1372 # for all other cases, raise for now (similarly as what happens in
#    1373 # Series.__array_prepare__)
# -> 1374 raise TypeError(
#    1375     f"Object with dtype {self.dtype} cannot perform "
#    1376     f"the numpy op {ufunc.__name__}"
#    1377 )
#
# TypeError: Object with dtype category cannot perform the numpy op add

# %%
x = "awesome"

def myfunc():
    x = "fantastic"
    print("Python is " + x)

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic
# Python is awesome

# %% [markdown]
# ### The global Keyword
#
# - Normalmente, cuando se crea una variable adentro de una función, esta variable es local y sólo puede ser usada adentro de la función.
#
# - Sin embargo, para crear una variable global desde dentro de una función, se puede utilizar la *palabra clave* **global**

# %%
def myfunc():
    global x
    x = "UUUUUUFAAAAA"

myfunc()

print("Python is " + x)
# Out:
# Python is UUUUUUFAAAAA

# %% [markdown]
# - También se utiliza la palabra clave **global** para cambiar el valor de una variable global desde dentro de una función

# %%
x = "awesome"

def myfunc():
    global x
    x = "fantastic"

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic
